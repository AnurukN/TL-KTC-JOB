# %% [markdown]
# # Setting

# %% [markdown]
# ## Create file from contact and prepare training file.

# %%
#importing some lib and set display table.
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', None)

# %%
t_0119_data = pd.read_csv('training_b_ac_st_t_0119.csv' ,header = 0,sep = ',', encoding = "utf-8-sig", index_col = 0)
t_0219_data = pd.read_csv('training_b_ac_st_t_0219.csv' ,header = 0,sep = ',', encoding = "utf-8-sig", index_col = 0)

# %%
t_0219_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 94 entries, 0 to 93
# Data columns (total 50 columns):
# CUSTOMER_ID                  94 non-null int64
# Gender                       94 non-null object
# MONTHLY_INCOME_RL            94 non-null float64
# Marital_status               94 non-null object
# Mobilephone_fg               94 non-null object
# Officephone_fg               94 non-null object
# Homephone_fg                 94 non-null object
# NO_OF_CHILD                  94 non-null float64
# Occupation                   94 non-null object
# Total_Credit_Limit           94 non-null float64
# Customer_Status              94 non-null object
# Is_Staff                     94 non-null object
# Is_KTC_Credit_Card_Holder    94 non-null object
# Age                          94 non-null float64
# Credit_Limit                 94 non-null float64
# Current_Balance              94 non-null float64
# Card_Age                     94 non-null float64
# ...

# %%
train = pd.concat([t_0119_data, t_0219_data], ignore_index=True)

# %%
train.sort_values(['CUSTOMER_ID'])
# Out:
#      CUSTOMER_ID  Gender  MONTHLY_INCOME_RL Marital_status Mobilephone_fg  \
# 0        1045856    Male            35680.0         Single              Y
# 92       1045856    Male            35680.0         Single              Y
# 93       1212490  Female            33940.0        Married              Y
# 1        1212490  Female            33940.0        Married              Y
# 94       1330974  Female            42000.0         Single              Y
# 2        1330974  Female            42000.0         Single              Y
# 95       1890904  Female            43570.0        Married              Y
# 96       1890904  Female            43570.0        Married              Y
# 5        1890904  Female            43570.0        Married              Y
# 3        1890904  Female            43570.0        Married              Y
# 4        1890904  Female            43570.0        Married              Y
# 97       3215097  Female            23000.0         Single              Y
# ...

# %%
train.to_csv('training_0119_to_0219.csv', encoding = "utf-8-sig")
